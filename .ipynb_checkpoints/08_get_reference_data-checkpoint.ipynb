# %%
import pandas as pd
import numpy as np

from datetime import date, datetime, timedelta, timezone
import os
import json
import requests
import time
import yaml
from itertools import chain

# %% [markdown]
# ## 0. Load reference data

# %%
DATA_DRAGON_PATH = './data/data_dragon/'
os.makedirs(os.path.join(DATA_DRAGON_PATH, 'set13'), exist_ok=True)

# %% [markdown]
# ### Units

# %%
# champion data
with open(os.path.join(DATA_DRAGON_PATH, 'tft-champion.json'), 'r') as file:
    CHAMP_DICT = json.load(file)

# %%
# filter for set 13 units
SET13_CHAMPS = {k.split('/')[-1]: v for (k, v) in CHAMP_DICT['data'].items() if k.startswith('Maps/Shipping/Map22/Sets/TFTSet13/Shop/') or k.startswith('Maps/Shipping/Map22/Sets/TFTSet13_Evolved/Shop/')}

# %%
SET13_CHAMPS
# Out:
# {'TFT13_Singed': {'id': 'TFT13_Singed',
#   'name': 'Singed',
#   'tier': 1,
#   'image': {'full': 'TFT13_Singed.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 192,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_RenataGlasc': {'id': 'TFT13_RenataGlasc',
#   'name': 'Renata Glasc',
#   'tier': 2,
#   'image': {'full': 'TFT13_RenataGlasc.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 240,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Silco': {'id': 'TFT13_Silco',
#   'name': 'Silco',
#   'tier': 4,
#   'image': {'full': 'TFT13_Silco.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 288,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Camille': {'id': 'TFT13_Camille',
#   'name': 'Camille',
#   'tier': 2,
#   'image': {'full': 'TFT13_Camille.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 336,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Blitzcrank': {'id': 'TFT13_Blitzcrank',
#   'name': 'Blitzcrank',
#   'tier': 3,
#   'image': {'full': 'TFT13_Blitzcrank.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 384,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Vi': {'id': 'TFT13_Vi',
#   'name': 'Vi',
#   'tier': 4,
#   'image': {'full': 'TFT13_Vi.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 432,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Caitlyn': {'id': 'TFT13_Caitlyn',
#   'name': 'Caitlyn',
#   'tier': 5,
#   'image': {'full': 'TFT13_Caitlyn.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 0,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Ekko': {'id': 'TFT13_Ekko',
#   'name': 'Ekko',
#   'tier': 4,
#   'image': {'full': 'TFT13_Ekko.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 48,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Amumu': {'id': 'TFT13_Amumu',
#   'name': 'Amumu',
#   'tier': 1,
#   'image': {'full': 'TFT13_Amumu.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 96,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Malzahar': {'id': 'TFT13_Malzahar',
#   'name': 'Malzahar',
#   'tier': 5,
#   'image': {'full': 'TFT13_Malzahar.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 144,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_DrMundo': {'id': 'TFT13_DrMundo',
#   'name': 'Dr. Mundo',
#   'tier': 4,
#   'image': {'full': 'TFT13_DrMundo.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 192,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Twitch': {'id': 'TFT13_Twitch',
#   'name': 'Twitch',
#   'tier': 4,
#   'image': {'full': 'TFT13_Twitch.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 240,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Akali': {'id': 'TFT13_Akali',
#   'name': 'Akali',
#   'tier': 2,
#   'image': {'full': 'TFT13_Akali.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 288,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Sett': {'id': 'TFT13_Sett',
#   'name': 'Sett',
#   'tier': 2,
#   'image': {'full': 'TFT13_Sett.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 336,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Ezreal': {'id': 'TFT13_Ezreal',
#   'name': 'Ezreal',
#   'tier': 3,
#   'image': {'full': 'TFT13_Ezreal.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 384,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Illaoi': {'id': 'TFT13_Illaoi',
#   'name': 'Illaoi',
#   'tier': 4,
#   'image': {'full': 'TFT13_Illaoi.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 432,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Draven': {'id': 'TFT13_Draven',
#   'name': 'Draven',
#   'tier': 1,
#   'image': {'full': 'TFT13_Draven.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 0,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Rell': {'id': 'TFT13_Rell',
#   'name': 'Rell',
#   'tier': 2,
#   'image': {'full': 'TFT13_Rell.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 48,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Cassiopeia': {'id': 'TFT13_Cassiopeia',
#   'name': 'Cassiopeia',
#   'tier': 3,
#   'image': {'full': 'TFT13_Cassiopeia.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 96,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Vladimir': {'id': 'TFT13_Vladimir',
#   'name': 'Vladimir',
#   'tier': 2,
#   'image': {'full': 'TFT12_Vladimir.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 144,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Elise': {'id': 'TFT13_Elise',
#   'name': 'Elise',
#   'tier': 4,
#   'image': {'full': 'TFT13_Elise.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 192,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_LeBlanc': {'id': 'TFT13_LeBlanc',
#   'name': 'LeBlanc',
#   'tier': 5,
#   'image': {'full': 'TFT13_LeBlanc.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 240,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Heimerdinger': {'id': 'TFT13_Heimerdinger',
#   'name': 'Heimerdinger',
#   'tier': 4,
#   'image': {'full': 'TFT13_Heimerdinger.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 288,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Jayce': {'id': 'TFT13_Jayce',
#   'name': 'Jayce',
#   'tier': 5,
#   'image': {'full': 'TFT13_Jayce.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 336,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Trundle': {'id': 'TFT13_Trundle',
#   'name': 'Trundle',
#   'tier': 1,
#   'image': {'full': 'TFT13_Trundle.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 384,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Ziggs': {'id': 'TFT13_Ziggs',
#   'name': 'Ziggs',
#   'tier': 2,
#   'image': {'full': 'TFT13_Ziggs.TFT_Set13.png',
#    'sprite': 'tft-champion3.png',
#    'group': 'tft-champion',
#    'x': 432,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Rumble': {'id': 'TFT13_Rumble',
#   'name': 'Rumble',
#   'tier': 5,
#   'image': {'full': 'TFT13_Rumble.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 0,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Gremlin': {'id': 'TFT13_Gremlin',
#   'name': 'Smeech',
#   'tier': 3,
#   'image': {'full': 'TFT13_Gremlin.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 48,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Lieutenant': {'id': 'TFT13_Lieutenant',
#   'name': 'Sevika',
#   'tier': 5,
#   'image': {'full': 'TFT13_Lieutenant.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 96,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Chainsaw': {'id': 'TFT13_Chainsaw',
#   'name': 'Renni',
#   'tier': 3,
#   'image': {'full': 'TFT13_Chainsaw.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 144,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Beardy': {'id': 'TFT13_Beardy',
#   'name': 'Loris',
#   'tier': 3,
#   'image': {'full': 'TFT13_Beardy.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 192,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Fish': {'id': 'TFT13_Fish',
#   'name': 'Steb',
#   'tier': 1,
#   'image': {'full': 'TFT13_Fish.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 240,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Shooter': {'id': 'TFT13_Shooter',
#   'name': 'Maddie',
#   'tier': 1,
#   'image': {'full': 'TFT13_Shooter.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 288,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Blue': {'id': 'TFT13_Blue',
#   'name': 'Powder',
#   'tier': 1,
#   'image': {'full': 'TFT13_Blue.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 336,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Prime': {'id': 'TFT13_Prime',
#   'name': 'Vander',
#   'tier': 2,
#   'image': {'full': 'TFT13_Prime.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 384,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_FlyGuy': {'id': 'TFT13_FlyGuy',
#   'name': 'Scar',
#   'tier': 3,
#   'image': {'full': 'TFT13_Flyguy.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 432,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_NunuWillump': {'id': 'TFT13_NunuWillump',
#   'name': 'Nunu & Willump',
#   'tier': 3,
#   'image': {'full': 'TFT13_NunuWillump.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 0,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Jinx': {'id': 'TFT13_Jinx',
#   'name': 'Jinx',
#   'tier': 5,
#   'image': {'full': 'TFT13_Jinx.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 48,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Zeri': {'id': 'TFT13_Zeri',
#   'name': 'Zeri',
#   'tier': 2,
#   'image': {'full': 'TFT13_Zeri.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 96,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Red': {'id': 'TFT13_Red',
#   'name': 'Violet',
#   'tier': 1,
#   'image': {'full': 'TFT13_Red.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 144,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Nami': {'id': 'TFT13_Nami',
#   'name': 'Nami',
#   'tier': 3,
#   'image': {'full': 'TFT13_Nami.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 192,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Corki': {'id': 'TFT13_Corki',
#   'name': 'Corki',
#   'tier': 4,
#   'image': {'full': 'TFT13_Corki.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 240,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Garen': {'id': 'TFT13_Garen',
#   'name': 'Garen',
#   'tier': 4,
#   'image': {'full': 'TFT13_Garen.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 288,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Vex': {'id': 'TFT13_Vex',
#   'name': 'Vex',
#   'tier': 1,
#   'image': {'full': 'TFT13_Vex.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 336,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Nocturne': {'id': 'TFT13_Nocturne',
#   'name': 'Nocturne',
#   'tier': 2,
#   'image': {'full': 'TFT13_Nocturne.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 384,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Darius': {'id': 'TFT13_Darius',
#   'name': 'Darius',
#   'tier': 1,
#   'image': {'full': 'TFT13_Darius.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 432,
#    'y': 48,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Irelia': {'id': 'TFT13_Irelia',
#   'name': 'Irelia',
#   'tier': 1,
#   'image': {'full': 'TFT13_Irelia.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 0,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Ambessa': {'id': 'TFT13_Ambessa',
#   'name': 'Ambessa',
#   'tier': 4,
#   'image': {'full': 'TFT13_Ambessa.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 48,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Zyra': {'id': 'TFT13_Zyra',
#   'name': 'Zyra',
#   'tier': 1,
#   'image': {'full': 'TFT13_Zyra.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 96,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Gangplank': {'id': 'TFT13_Gangplank',
#   'name': 'Gangplank',
#   'tier': 3,
#   'image': {'full': 'TFT13_Gangplank.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 144,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Leona': {'id': 'TFT13_Leona',
#   'name': 'Leona',
#   'tier': 2,
#   'image': {'full': 'TFT13_Leona.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 192,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_KogMaw': {'id': 'TFT13_KogMaw',
#   'name': "Kog'Maw",
#   'tier': 3,
#   'image': {'full': 'TFT13_KogMaw.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 240,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_TwistedFate': {'id': 'TFT13_TwistedFate',
#   'name': 'Twisted Fate',
#   'tier': 3,
#   'image': {'full': 'TFT13_TwistedFate.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 288,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Lux': {'id': 'TFT13_Lux',
#   'name': 'Lux',
#   'tier': 1,
#   'image': {'full': 'TFT13_Lux.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 336,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Mordekaiser': {'id': 'TFT13_Mordekaiser',
#   'name': 'Mordekaiser',
#   'tier': 5,
#   'image': {'full': 'TFT13_Mordekaiser.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 384,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Morgana': {'id': 'TFT13_Morgana',
#   'name': 'Morgana',
#   'tier': 1,
#   'image': {'full': 'TFT13_Morgana.TFT_Set13.png',
#    'sprite': 'tft-champion4.png',
#    'group': 'tft-champion',
#    'x': 432,
#    'y': 96,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Tristana': {'id': 'TFT13_Tristana',
#   'name': 'Tristana',
#   'tier': 2,
#   'image': {'full': 'TFT13_Tristana.TFT_Set13.png',
#    'sprite': 'tft-champion5.png',
#    'group': 'tft-champion',
#    'x': 0,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Swain': {'id': 'TFT13_Swain',
#   'name': 'Swain',
#   'tier': 3,
#   'image': {'full': 'TFT13_Swain.TFT_Set13.png',
#    'sprite': 'tft-champion5.png',
#    'group': 'tft-champion',
#    'x': 48,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Urgot': {'id': 'TFT13_Urgot',
#   'name': 'Urgot',
#   'tier': 2,
#   'image': {'full': 'TFT13_Urgot.TFT_Set13.png',
#    'sprite': 'tft-champion5.png',
#    'group': 'tft-champion',
#    'x': 96,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Zoe': {'id': 'TFT13_Zoe',
#   'name': 'Zoe',
#   'tier': 4,
#   'image': {'full': 'TFT13_Zoe.TFT_Set13.png',
#    'sprite': 'tft-champion5.png',
#    'group': 'tft-champion',
#    'x': 144,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Viktor': {'id': 'TFT13_Viktor',
#   'name': 'Viktor',
#   'tier': 6,
#   'image': {'full': 'TFT13_Viktor.TFT_Set13_Evolved.png',
#    'sprite': 'tft-champion5.png',
#    'group': 'tft-champion',
#    'x': 192,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_MissMage': {'id': 'TFT13_MissMage',
#   'name': 'Mel',
#   'tier': 6,
#   'image': {'full': 'TFT13_MissMage.TFT_Set13_Evolved.png',
#    'sprite': 'tft-champion5.png',
#    'group': 'tft-champion',
#    'x': 240,
#    'y': 0,
#    'w': 48,
#    'h': 48}},
#  'TFT13_Warwick': {'id': 'TFT13_Warwick',
#   'name': 'Warwick',
#   'tier': 6,
#   'image': {'full': 'TFT13_Warwick.TFT_Set13_Evolved.png',
#    'sprite': 'tft-champion5.png',
#    'group': 'tft-champion',
#    'x': 288,
#    'y': 0,
#    'w': 48,
#    'h': 48}}}

# %%
with open(os.path.join(DATA_DRAGON_PATH, 'set13', 'units.json'), 'w', encoding='utf-8') as file:
    json.dump(SET13_CHAMPS, file)

# %% [markdown]
# ### Items

# %%
# items data
with open(os.path.join(DATA_DRAGON_PATH, 'tft-item.json'), 'r') as file:
    ITEMS_DICT = json.load(file)

# %%
list([i for i in ITEMS_DICT['data'].keys() if '_Ornn' in i])
# Out:
# ['TFT4_Item_OrnnAnimaVisage',
#  'TFT4_Item_OrnnDeathsDefiance',
#  'TFT4_Item_OrnnEternalWinter',
#  'TFT4_Item_OrnnTheCollector',
#  'TFT4_Item_OrnnInfinityForce',
#  'TFT4_Item_OrnnMuramana',
#  'TFT4_Item_OrnnObsidianCleaver',
#  'TFT4_Item_OrnnRanduinsSanctum',
#  'TFT4_Item_OrnnZhonyasParadox',
#  'TFT9_Item_OrnnHullbreaker',
#  'TFT9_Item_OrnnTrickstersGlass',
#  'TFT9_Item_OrnnDeathfireGrasp',
#  'TFT9_Item_OrnnHorizonFocus',
#  'TFT9_Item_OrnnPrototypeForge',
#  'TFT4_Item_OrnnRocketPropelledFist',
#  'TFT9_Item_OrnnDuskbladeOfDraktharr']

# %%
# filter for set 13 items
def is_set13_items(val):
    if val.startswith('TFT_Item_') and not val.startswith('TFT_Item_Debug'):
        return True
    elif val.startswith('TFT_Consumable_'):
        return True
    elif val.startswith('TFT13_'):
        return True
    elif 'Shimmerscale' in val:
        return True
    elif '_Ornn' in val:
        return True
    elif 'RadiantItems' in val:
        return True
    return False
    
SET13_ITEMS = {k: v for (k, v) in ITEMS_DICT['data'].items() if is_set13_items(k)}

# %%
sorted(list(SET13_ITEMS.keys()))
# Out:
# ['Set5_RadiantItems/TFT5_Item_AdaptiveHelmRadiant',
#  'Set5_RadiantItems/TFT5_Item_ArchangelsStaffRadiant',
#  'Set5_RadiantItems/TFT5_Item_BloodthirsterRadiant',
#  'Set5_RadiantItems/TFT5_Item_BlueBuffRadiant',
#  'Set5_RadiantItems/TFT5_Item_BrambleVestRadiant',
#  'Set5_RadiantItems/TFT5_Item_CrownguardRadiant',
#  'Set5_RadiantItems/TFT5_Item_DeathbladeRadiant',
#  'Set5_RadiantItems/TFT5_Item_DragonsClawRadiant',
#  'Set5_RadiantItems/TFT5_Item_FrozenHeartRadiant',
#  'Set5_RadiantItems/TFT5_Item_GargoyleStoneplateRadiant',
#  'Set5_RadiantItems/TFT5_Item_GiantSlayerRadiant',
#  'Set5_RadiantItems/TFT5_Item_GuardianAngelRadiant',
#  'Set5_RadiantItems/TFT5_Item_GuinsoosRagebladeRadiant',
#  'Set5_RadiantItems/TFT5_Item_HandOfJusticeRadiant',
#  'Set5_RadiantItems/TFT5_Item_HextechGunbladeRadiant',
#  'Set5_RadiantItems/TFT5_Item_InfinityEdgeRadiant',
#  'Set5_RadiantItems/TFT5_Item_IonicSparkRadiant',
#  'Set5_RadiantItems/TFT5_Item_JeweledGauntletRadiant',
#  'Set5_RadiantItems/TFT5_Item_LastWhisperRadiant',
#  'Set5_RadiantItems/TFT5_Item_LeviathanRadiant',
#  'Set5_RadiantItems/TFT5_Item_MorellonomiconRadiant',
#  'Set5_RadiantItems/TFT5_Item_NightHarvesterRadiant',
#  'Set5_RadiantItems/TFT5_Item_QuicksilverRadiant',
#  'Set5_RadiantItems/TFT5_Item_RabadonsDeathcapRadiant',
#  'Set5_RadiantItems/TFT5_Item_RapidFirecannonRadiant',
#  'Set5_RadiantItems/TFT5_Item_RedemptionRadiant',
#  'Set5_RadiantItems/TFT5_Item_RunaansHurricaneRadiant',
#  'Set5_RadiantItems/TFT5_Item_SpearOfShojinRadiant',
#  'Set5_RadiantItems/TFT5_Item_SpectralGauntletRadiant',
#  'Set5_RadiantItems/TFT5_Item_StatikkShivRadiant',
#  'Set5_RadiantItems/TFT5_Item_SteraksGageRadiant',
#  'Set5_RadiantItems/TFT5_Item_SunfireCapeRadiant',
#  'Set5_RadiantItems/TFT5_Item_ThiefsGlovesRadiant',
#  'Set5_RadiantItems/TFT5_Item_TitansResolveRadiant',
#  'Set5_RadiantItems/TFT5_Item_TrapClawRadiant',
#  'Set5_RadiantItems/TFT5_Item_WarmogsArmorRadiant',
#  'Set5_RadiantItems/TFT5_Item_ZzRotPortalRadiant',
#  'TFT13_AnotherAnomaly_Item',
#  'TFT13_Crime_Armory/TFT13_Item_Crime_ArmoryCashout',
#  'TFT13_Crime_Armory/TFT13_Item_Crime_ArmoryContinue',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Chainsaw',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Chainsaw_2Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Chainsaw_3Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Gremlin',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Gremlin_2Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Gremlin_3Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Lieutenant',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Lieutenant_2Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Lieutenant_3Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_RenataGlasc',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_RenataGlasc_2Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_RenataGlasc_3Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Silco',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Silco_2Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Silco_3Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Singed',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Singed_2Star',
#  'TFT13_Crime_Illegal_Items/ChampionItems/TFT13_ChampionItem_Singed_3Star',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Bronze_ChemGrips',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Bronze_MageGuard',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Bronze_MiningGauntlet',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Consumable_LesserShimmerDuplicator',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Consumable_PerfectedShimmer',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Consumable_ShimmerDuplicator',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_DestabilizedChemtank',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_ExecutionersVorpalblade',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_FleshRipper',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_PiltovenHexplating',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_ShimmerBloom',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_UnleashedToxins',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_VirulentVirus',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Gold_VoltaicSaber',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_OmegaPrismatic_DimensionalHeirloom',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_DestabilizedChemtank',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_ExecutionersVorpalblade',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_FleshRipper',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_PiltovenHexplating',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_ShimmerBloom',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_UnleashedToxins',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_VirulentVirus',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Prismatic_VoltaicSaber',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_DestabilizedChemtank',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_ExecutionersVorpalblade',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_FleshRipper',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_PiltovenHexplating',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_ShimmerBloom',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_UnleashedToxins',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_VirulentVirus',
#  'TFT13_Crime_Illegal_Items/TFT13_Crime_Silver_VoltaicSaber',
#  'TFT13_EmblemItems/TFT13_Item_AcademyEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_AmbusherEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_AutomataEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_BruiserEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_CabalEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_ChallengerEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_DemolitionistEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_ExperimentEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_FamilyEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_HoverboardEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_InfusedEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_InvokerEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_PitFighterEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_RebelEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_ScrapEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_SniperEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_SorcererEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_SquadEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_TitanEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_WarbandEmblemItem',
#  'TFT13_EmblemItems/TFT13_Item_WatcherEmblemItem',
#  'TFT13_GoopBuff_Miniaturize_Item',
#  'TFT13_Items/TFT13_GoopBuff_VoraciousAppetite_Consumable',
#  'TFT13_Items/TFT13_Item_SquadStolenItem',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_3Star',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_Flamethrower',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_Pass',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_PertriciteRod',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_RepairingMicrobots',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_SelfDestructButton',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_SuperPass',
#  'TFT13_JunkerKingUpgrades/TFT13_JunkerKing_Tankbuster',
#  'TFT4_Item_OrnnAnimaVisage',
#  'TFT4_Item_OrnnDeathsDefiance',
#  'TFT4_Item_OrnnEternalWinter',
#  'TFT4_Item_OrnnInfinityForce',
#  'TFT4_Item_OrnnMuramana',
#  'TFT4_Item_OrnnObsidianCleaver',
#  'TFT4_Item_OrnnRanduinsSanctum',
#  'TFT4_Item_OrnnRocketPropelledFist',
#  'TFT4_Item_OrnnTheCollector',
#  'TFT4_Item_OrnnZhonyasParadox',
#  'TFT7_ShimmerscaleItems/TFT7_Item_ShimmerscaleDeterminedInvestor',
#  'TFT7_ShimmerscaleItems/TFT7_Item_ShimmerscaleDiamondHands',
#  'TFT7_ShimmerscaleItems/TFT7_Item_ShimmerscaleGamblersBlade',
#  'TFT7_ShimmerscaleItems/TFT7_Item_ShimmerscaleGamblersBlade_HR',
#  'TFT7_ShimmerscaleItems/TFT7_Item_ShimmerscaleHeartOfGold',
#  'TFT7_ShimmerscaleItems/TFT7_Item_ShimmerscaleHeartOfGold_HR',
#  'TFT7_ShimmerscaleItems/TFT7_Item_ShimmerscaleMogulsMail',
#  'TFT9_Item_OrnnDeathfireGrasp',
#  'TFT9_Item_OrnnDuskbladeOfDraktharr',
#  'TFT9_Item_OrnnHorizonFocus',
#  'TFT9_Item_OrnnHullbreaker',
#  'TFT9_Item_OrnnPrototypeForge',
#  'TFT9_Item_OrnnTrickstersGlass',
#  'TFT_Consumable_ChampionDuplicator_I',
#  'TFT_Consumable_ChampionDuplicator_III',
#  'TFT_Consumable_ItemRemover',
#  'TFT_Consumable_ItemRemover_UsesLeft10',
#  'TFT_Consumable_ItemRemover_UsesLeft2',
#  'TFT_Consumable_ItemRemover_UsesLeft3',
#  'TFT_Consumable_ItemRemover_UsesLeft4',
#  'TFT_Consumable_ItemRemover_UsesLeft5',
#  'TFT_Consumable_ItemRemover_UsesLeft6',
#  'TFT_Consumable_ItemRemover_UsesLeft7',
#  'TFT_Consumable_ItemRemover_UsesLeft8',
#  'TFT_Consumable_ItemRemover_UsesLeft9',
#  'TFT_Consumable_ItemReroller',
#  'TFT_Consumable_ItemReroller_UsesLeft10',
#  'TFT_Consumable_ItemReroller_UsesLeft2',
#  'TFT_Consumable_ItemReroller_UsesLeft3',
#  'TFT_Consumable_ItemReroller_UsesLeft4',
#  'TFT_Consumable_ItemReroller_UsesLeft5',
#  'TFT_Consumable_ItemReroller_UsesLeft6',
#  'TFT_Consumable_ItemReroller_UsesLeft7',
#  'TFT_Consumable_ItemReroller_UsesLeft8',
#  'TFT_Consumable_ItemReroller_UsesLeft9',
#  'TFT_Consumable_MasterworkUpgrade',
#  'TFT_Consumable_NeekosHelp',
#  'TFT_Consumable_ShopReroller',
#  'TFT_Consumable_TrainingDummy',
#  'TFT_Consumable_TrashToTreasure_Reforger',
#  'TFT_Item_AdaptiveHelm',
#  'TFT_Item_AegisOfTheLegion',
#  'TFT_Item_ArchangelsStaff',
#  'TFT_Item_Artifact_BlightingJewel',
#  'TFT_Item_Artifact_CursedVampiricScepter',
#  'TFT_Item_Artifact_Fishbones',
#  'TFT_Item_Artifact_ForbiddenIdol',
#  'TFT_Item_Artifact_HorizonFocus',
#  'TFT_Item_Artifact_InnervatingLocket',
#  'TFT_Item_Artifact_LichBane',
#  'TFT_Item_Artifact_LightshieldCrest',
#  'TFT_Item_Artifact_LudensTempest',
#  'TFT_Item_Artifact_Mittens',
#  'TFT_Item_Artifact_ProwlersClaw',
#  'TFT_Item_Artifact_RapidFirecannon',
#  'TFT_Item_Artifact_SeekersArmguard',
#  'TFT_Item_Artifact_SilvermereDawn',
#  'TFT_Item_Artifact_SpectralCutlass',
#  'TFT_Item_Artifact_SuspiciousTrenchCoat',
#  'TFT_Item_Artifact_TalismanOfAscension',
#  'TFT_Item_Artifact_UnendingDespair',
#  'TFT_Item_Artifact_WitsEnd',
#  'TFT_Item_BFSword',
#  'TFT_Item_BansheesVeil',
#  'TFT_Item_Bloodthirster',
#  'TFT_Item_BlueBuff',
#  'TFT_Item_BrambleVest',
#  'TFT_Item_ChainVest',
#  'TFT_Item_Chalice',
#  'TFT_Item_Crownguard',
#  'TFT_Item_Deathblade',
#  'TFT_Item_DragonsClaw',
#  'TFT_Item_EmptyBag',
#  'TFT_Item_EternalFlame',
#  'TFT_Item_ForceOfNature',
#  'TFT_Item_FrozenHeart',
#  'TFT_Item_FryingPan',
#  'TFT_Item_GargoyleStoneplate',
#  'TFT_Item_GiantsBelt',
#  'TFT_Item_GuardianAngel',
#  'TFT_Item_GuinsoosRageblade',
#  'TFT_Item_HextechGunblade',
#  'TFT_Item_InfinityEdge',
#  'TFT_Item_IonicSpark',
#  'TFT_Item_JeweledGauntlet',
#  'TFT_Item_LastWhisper',
#  'TFT_Item_Leviathan',
#  'TFT_Item_LocketOfTheIronSolari',
#  'TFT_Item_MadredsBloodrazor',
#  'TFT_Item_Moonstone',
#  'TFT_Item_Morellonomicon',
#  'TFT_Item_NeedlesslyLargeRod',
#  'TFT_Item_NegatronCloak',
#  'TFT_Item_NightHarvester',
#  'TFT_Item_PowerGauntlet',
#  'TFT_Item_Quicksilver',
#  'TFT_Item_RabadonsDeathcap',
#  'TFT_Item_RadiantVirtue',
#  'TFT_Item_RapidFireCannon',
#  'TFT_Item_RecurveBow',
#  'TFT_Item_RedBuff',
#  'TFT_Item_Redemption',
#  'TFT_Item_RunaansHurricane',
#  'TFT_Item_SentinelSwarm',
#  'TFT_Item_Shroud',
#  'TFT_Item_SparringGloves',
#  'TFT_Item_Spatula',
#  'TFT_Item_SpearOfShojin',
#  'TFT_Item_SpectralGauntlet',
#  'TFT_Item_Spite',
#  'TFT_Item_StatikkShiv',
#  'TFT_Item_SteraksGage',
#  'TFT_Item_SupportKnightsVow',
#  'TFT_Item_TacticiansRing',
#  'TFT_Item_TacticiansScepter',
#  'TFT_Item_TearOfTheGoddess',
#  'TFT_Item_ThiefsGloves',
#  'TFT_Item_TitanicHydra',
#  'TFT_Item_TitansResolve',
#  'TFT_Item_UnstableConcoction',
#  'TFT_Item_UnstableTreasureChest',
#  'TFT_Item_UnusableSlot',
#  'TFT_Item_WarmogsArmor',
#  'TFT_Item_ZekesHerald',
#  'TFT_Item_Zephyr']

# %%
SET13_ITEMS['TFT13_GoopBuff_Miniaturize_Item']
# Out:
# {'id': 'TFT13_GoopBuff_Miniaturize_Item',
#  'name': 'Miniature Champion',
#  'image': {'full': 'TFT13_GoopBuff_Miniaturize_Item.png',
#   'sprite': 'tft-item9.png',
#   'group': 'tft-item',
#   'x': 48,
#   'y': 48,
#   'w': 48,
#   'h': 48}}

# %%
with open(os.path.join(DATA_DRAGON_PATH, 'set13', 'items.json'), 'w', encoding='utf-8') as file:
    json.dump(SET13_ITEMS, file)

# %% [markdown]
# ### Traits

# %%
# items data
with open(os.path.join(DATA_DRAGON_PATH, 'tft-trait.json'), 'r') as file:
    TRAITS_DICT = json.load(file)

# %%
# filter for set 13 traits   
SET13_TRAITS = {k: v for (k, v) in TRAITS_DICT['data'].items() if k.startswith('TFT13_')}

# %%
list(SET13_TRAITS.keys())
# Out:
# ['TFT13_Academy',
#  'TFT13_Ambassador',
#  'TFT13_Ambusher',
#  'TFT13_Bruiser',
#  'TFT13_Cabal',
#  'TFT13_Challenger',
#  'TFT13_Crime',
#  'TFT13_Experiment',
#  'TFT13_Family',
#  'TFT13_FormSwapper',
#  'TFT13_Hextech',
#  'TFT13_Hoverboard',
#  'TFT13_Invoker',
#  'TFT13_Martialist',
#  'TFT13_Pugilist',
#  'TFT13_Rebel',
#  'TFT13_Scrap',
#  'TFT13_Sniper',
#  'TFT13_Squad',
#  'TFT13_Titan',
#  'TFT13_Warband',
#  'TFT13_Watcher',
#  'TFT13_JunkerKing',
#  'TFT13_Sorcerer',
#  'TFT13_Infused',
#  'TFT13_Teamup_BloodBrothers',
#  'TFT13_Teamup_Sisters',
#  'TFT13_Teamup_Mentorship',
#  'TFT13_HighRoller',
#  'TFT13_Teamup_UnlikelyDuo',
#  'TFT13_Teamup_Geniuses',
#  'TFT13_Teamup_Reunion',
#  'TFT13_Teamup_Menaces',
#  'TFT13_MissMageTrait',
#  'TFT13_MachineHerald',
#  'TFT13_BloodHunter',
#  'TFT13_Teamup_Betrayal',
#  'TFT13_RammusTrait']

# %%
with open(os.path.join(DATA_DRAGON_PATH, 'set13', 'traits.json'), 'w', encoding='utf-8') as file:
    json.dump(SET13_TRAITS, file)

# %% [markdown]
# ### Anomalies
# Anomaly is a new game mechanic introduced in set 13 that allows players to upgrade one unit on their board with a special effect, making them more powerful.

# %%
# items data
with open(os.path.join(DATA_DRAGON_PATH, 'tft-anomalies.json'), 'r') as file:
    ANOMALIES_DICT = json.load(file)

# %%
# filter for set 13 anomalies
   
SET13_ANOMALIES = {k: v for (k, v) in ANOMALIES_DICT['data'].items() if k.startswith('TFT13_GoopBuff_')}

# %%
list(SET13_ANOMALIES.keys())
# Out:
# ['TFT13_GoopBuff_BerserkerRage',
#  'TFT13_GoopBuff_Bulwark',
#  'TFT13_GoopBuff_DualWielding',
#  'TFT13_GoopBuff_EagleEye',
#  'TFT13_GoopBuff_Fortified',
#  'TFT13_GoopBuff_Freestyling',
#  'TFT13_GoopBuff_Hypervelocity',
#  'TFT13_GoopBuff_KillStreak',
#  'TFT13_GoopBuff_MagicTraining',
#  'TFT13_GoopBuff_ShouldertheBurden',
#  'TFT13_GoopBuff_StrengthTraining',
#  'TFT13_GoopBuff_TheFinisher',
#  'TFT13_GoopBuff_Thornskin',
#  'TFT13_GoopBuff_GiantSized',
#  'TFT13_GoopBuff_EnergyAbsorption',
#  'TFT13_GoopBuff_Bully',
#  'TFT13_GoopBuff_EssenceofNavori',
#  'TFT13_GoopBuff_AvalancheofArmor',
#  'TFT13_GoopBuff_TouchofFrost',
#  'TFT13_GoopBuff_Knockout',
#  'TFT13_GoopBuff_CenteroftheUniverse',
#  'TFT13_GoopBuff_CosmicRhythm',
#  'TFT13_GoopBuff_ArcanaOverwhelming',
#  'TFT13_GoopBuff_Invisibility',
#  'TFT13_GoopBuff_AllForOne',
#  'TFT13_GoopBuff_OneThousandCuts',
#  'TFT13_GoopBuff_MageArmor',
#  'TFT13_GoopBuff_AvariceIncarnate',
#  'TFT13_GoopBuff_EvenInDeath',
#  'TFT13_GoopBuff_TitanicStrikes',
#  'TFT13_GoopBuff_SlowCooker',
#  'TFT13_GoopBuff_HeavyHitter',
#  'TFT13_GoopBuff_LegacyOfShurima',
#  'TFT13_GoopBuff_ShareYourEnergy',
#  'TFT13_GoopBuff_Headhunter',
#  'TFT13_GoopBuff_CullTheWeak',
#  'TFT13_GoopBuff_SlimeTime',
#  'TFT13_GoopBuff_UnstoppableForce',
#  'TFT13_GoopBuff_Fireball',
#  'TFT13_GoopBuff_ScuttleFamiliar',
#  'TFT13_GoopBuff_CallingCard',
#  'TFT13_GoopBuff_MagicMind',
#  'TFT13_GoopBuff_ComebackStory',
#  'TFT13_GoopBuff_HardenedMind',
#  'TFT13_GoopBuff_SharpenedMind',
#  'TFT13_GoopBuff_DeftHands',
#  'TFT13_GoopBuff_PowerAbsorption',
#  'TFT13_GoopBuff_Miniaturize',
#  'TFT13_GoopBuff_DeepRoots',
#  'TFT13_GoopBuff_WolfFamiliars',
#  'TFT13_GoopBuff_CertainDeath',
#  'TFT13_GoopBuff_Dragonsoul',
#  'TFT13_GoopBuff_IntoTheUnknown',
#  'TFT13_GoopBuff_NothingWasted',
#  'TFT13_GoopBuff_UltimateHero',
#  'TFT13_GoopBuff_LaserEyes',
#  'TFT13_GoopBuff_HungerForPower',
#  'TFT13_GoopBuff_DramaticEntrance',
#  'TFT13_GoopBuff_Stoneskin',
#  'TFT13_GoopBuff_Repulsor',
#  'TFT13_GoopBuff_InfectiousAnomaly',
#  'TFT13_GoopBuff_Hivemind',
#  'TFT13_GoopBuff_VoraciousAppetite',
#  'TFT13_GoopBuff_BrutalClaws',
#  'TFT13_GoopBuff_VampiricAffinity',
#  'TFT13_GoopBuff_CyberneticEmpowerment',
#  'TFT13_GoopBuff_OneForAll',
#  'TFT13_GoopBuff_PowerUp',
#  'TFT13_GoopBuff_CultivatingMagic']

# %%
with open(os.path.join(DATA_DRAGON_PATH, 'set13', 'anomalies.json'), 'w', encoding='utf-8') as file:
    json.dump(SET13_ANOMALIES, file)
